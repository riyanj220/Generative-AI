# %%
import pandas as pd

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/GenerativeAINotebooks/datasets/
# Out:
# /content/drive/MyDrive/GenerativeAINotebooks/datasets

# %%
# !pwd
# Out:
# /content/drive/MyDrive/GenerativeAINotebooks/datasets

# %%
# !ls
# Out:
# 'IMDB Dataset.csv'

# %%
data_path = "/content/drive/MyDrive/GenerativeAINotebooks/datasets/IMDB Dataset.csv"

# %%
import csv

# %%
df = pd.read_csv(data_path, quoting=csv.QUOTE_NONE, on_bad_lines='skip', encoding='utf-8')

# %%
df.shape
# Out:
# (4020, 2)

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     narrative sublime. It's never included in critics' choices of Best Films but it should be. Still as poetic and powerful as when I first saw it over 17 years ago. I watch the 3 boxed sets every autumn for their 'mellow fruitfulness'. Inspired and inspiring."  \
# ...

# %%
df = df.head(100)

# %%
df.shape
# Out:
# (100, 2)

# %%
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     narrative sublime. It's never included in critics' choices of Best Films but it should be. Still as poetic and powerful as when I first saw it over 17 years ago. I watch the 3 boxed sets every autumn for their 'mellow fruitfulness'. Inspired and inspiring."  \
# ...

# %%
df['reviews'][3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'reviews'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1226000249.py in <cell line: 0>()
# ----> 1 df['reviews'][3]
#
# ...

# %%
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     narrative sublime. It's never included in critics' choices of Best Films but it should be. Still as poetic and powerful as when I first saw it over 17 years ago. I watch the 3 boxed sets every autumn for their 'mellow fruitfulness'. Inspired and inspiring."  \
# ...

# %% [markdown]
# ## **Reading a csv file and adding Column names to it**

# %%
df = pd.read_csv(data_path, quoting=csv.QUOTE_NONE, on_bad_lines='skip', encoding='utf-8',names=["Review", "Sentiment"], header=None)

# %%
df = df.head(100)

# %%
df
# Out:
#                                                Review Sentiment
# 0   narrative sublime. It's never included in crit...  positive
# 1   "This is by far the worst film I have seen in ...  negative
# 2   I saw this on the shelves at the rental place ...  negative
# 3   "This film is about a teen who is struggling w...  positive
# 4   Once again Elmer is faced with the dilemma of ...  positive
# ..                                                ...       ...
# 95  "The mood of this movie is pretty good and it ...  negative
# 96  don't see this. this was one of the dumbest mo...  negative
# 97  I can agree with other comments that there was...  positive
# 98  This movie is terrible. It's about some no bra...  negative
# 99  This movie was awful in the worst way: you jus...  negative
#
# [100 rows x 2 columns]

# %%
df['Review'][3]
# Out:
# '"This film is about a teen who is struggling with his social status in school. He is a ""Good Christian"" and feels that he is missing out on all the fun in high school. So he wishes he had never become one. After getting his wish and trying a worldly lifestyle he realizes that his quality of life has been dramatically diminished and wants to go back to being the person that he was. Good family-oriented film with a positive message of being proud of who you are even if you\'re not the most popular."'

# %% [markdown]
# ## **Using lowercase for reviews**

# %%
df['Review'] = df['Review'].str.lower()

# %%
df['Review'][3]
# Out:
# '"this film is about a teen who is struggling with his social status in school. he is a ""good christian"" and feels that he is missing out on all the fun in high school. so he wishes he had never become one. after getting his wish and trying a worldly lifestyle he realizes that his quality of life has been dramatically diminished and wants to go back to being the person that he was. good family-oriented film with a positive message of being proud of who you are even if you\'re not the most popular."'

# %%
df
# Out:
#                                                Review Sentiment
# 0   narrative sublime. it's never included in crit...  positive
# 1   "this is by far the worst film i have seen in ...  negative
# 2   i saw this on the shelves at the rental place ...  negative
# 3   "this film is about a teen who is struggling w...  positive
# 4   once again elmer is faced with the dilemma of ...  positive
# ..                                                ...       ...
# 95  "the mood of this movie is pretty good and it ...  negative
# 96  don't see this. this was one of the dumbest mo...  negative
# 97  i can agree with other comments that there was...  positive
# 98  this movie is terrible. it's about some no bra...  negative
# 99  this movie was awful in the worst way: you jus...  negative
#
# [100 rows x 2 columns]

# %% [markdown]
# ## **Removing html tags**

# %%
import re
def remove_html_tags(text):
  pattern = re.compile('<.*?>')
  return pattern.sub(r'', text)

# %%
text = "<html><body><p> Movie 1</p>"

# %%
remove_html_tags(text)
# Out:
# ' Movie 1'

# %%
df['Review'] = df['Review'].apply(remove_html_tags)

# %%
df['Review'][5]
# Out:
# "there was a reasonably good looking girl starring the film(zoe mclellan) but even her looks couldn't stop me from voting it the lowest possible - one.the plot is bad and irrational.what more can i say. the movie sucks."

# %% [markdown]
# ## ** Removing URL**

# %%
def remove_url(text):
  pattern = re.compile(r'https?://\S+|www\.\S+')
  return pattern.sub(r'', text)

# %%
text1 = "Checkout my youtube https://www.youtube.com Riyan J"
text2 = "Cehckout my linkedin https://www.linkedin.com/in/riyanj"
text3 = "Google search here www.google.com"

# %%
text2 = remove_url(text2)

# %%
text2
# Out:
# 'Cehckout my linkedin '

# %% [markdown]
# ## **Punctuation Handling**

# %%
import string,time
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
exclude = string.punctuation
exclude
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punc(text):
  for char in exclude:
    text = text.replace(char,'')
  return text

# %%
text = 'String. with punctuation?'

# %%
remove_punc(text)
# Out:
# 'String with punctuation'

# %%
start = time.time()
print(remove_punc(text))
time1 = time.time() - start
print(time1*50000)
# Out:
# String with punctuation
# 8.678436279296875

# %%
def remove_punc1(text):
  return text.translate(str.maketrans('','',exclude))

# %%
start = time.time()
print(remove_punc1(text))
time2 = time.time() - start
print(time2*50000)
# Out:
# String with punctuation
# 6.902217864990234

# %%
df['Review'][5]
# Out:
# "there was a reasonably good looking girl starring the film(zoe mclellan) but even her looks couldn't stop me from voting it the lowest possible - one.the plot is bad and irrational.what more can i say. the movie sucks."

# %%
df['Review'].apply(remove_punc1)
# Out:
# 0     narrative sublime its never included in critic...
# 1     this is by far the worst film i have seen in m...
# 2     i saw this on the shelves at the rental place ...
# 3     this film is about a teen who is struggling wi...
# 4     once again elmer is faced with the dilemma of ...
#                             ...
# 95    the mood of this movie is pretty good and it c...
# 96    dont see this this was one of the dumbest movi...
# 97    i can agree with other comments that there was...
# 98    this movie is terrible its about some no brain...
# 99    this movie was awful in the worst way you just...
# Name: Review, Length: 100, dtype: object

# %% [markdown]
# ## **Chat conversation Handling**

# %%
chat_words = {
    'AFAIK':'As Far As I Know',
    'AFK':'Away From Keyboard',
    'ASAP':'As Soon As Possible'
}


{
    "FYI": "For Your Information",
    "ASAP": "As Soon As Possible",
    "BRB": "Be Right Back",
    "BTW": "By The Way",
    "OMG": "Oh My God",
    "IMO": "In My Opinion",
    "LOL": "Laugh Out Loud",
    "TTYL": "Talk To You Later",
    "GTG": "Got To Go",
    "TTYT": "Talk To You Tomorrow",
    "IDK": "I Don't Know",
    "TMI": "Too Much Information",
    "IMHO": "In My Humble Opinion",
    "ICYMI": "In Case You Missed It",
    "AFAIK": "As Far As I Know",
    "BTW": "By The Way",
    "FAQ": "Frequently Asked Questions",
    "TGIF": "Thank God It's Friday",
    "FYA": "For Your Action",
    "ICYMI": "In Case You Missed It",
}
# Out:
# {'FYI': 'For Your Information',
#  'ASAP': 'As Soon As Possible',
#  'BRB': 'Be Right Back',
#  'BTW': 'By The Way',
#  'OMG': 'Oh My God',
#  'IMO': 'In My Opinion',
#  'LOL': 'Laugh Out Loud',
#  'TTYL': 'Talk To You Later',
#  'GTG': 'Got To Go',
#  'TTYT': 'Talk To You Tomorrow',
#  'IDK': "I Don't Know",
#  'TMI': 'Too Much Information',
#  'IMHO': 'In My Humble Opinion',
#  'ICYMI': 'In Case You Missed It',
#  'AFAIK': 'As Far As I Know',
#  'FAQ': 'Frequently Asked Questions',
#  'TGIF': "Thank God It's Friday",
#  'FYA': 'For Your Action'}

# %%
def chat_conversion(text):
    new_text = []
    for w in text.split():
        if w.upper() in chat_words:
            new_text.append(chat_words[w.upper()])
        else:
            new_text.append(w)
    return " ".join(new_text)

# %%
chat_conversion('Do this work ASAP')
# Out:
# 'Do this work As Soon As Possible'

# %% [markdown]
# ## **Incorrect Text Handling**

# %%
from textblob import TextBlob

# %%
incorrect_text = 'ceertain conditionas duriing seveal ggenerations aree moodified in the saame maner.'

textBlb = TextBlob(incorrect_text)

textBlb.correct().string
# Out:
# 'certain conditions during several generations are modified in the same manner.'

# %% [markdown]
# ## **Stopwords**

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
def remove_stopwords(text):
    new_text = []

    for word in text.split():
        if word in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(word)
    x = new_text[:]
    new_text.clear()
    return " ".join(x)

# %%
remove_stopwords('probably my all-time favorite movie, a story of selflessness, sacrifice and dedication to a noble cause, but it\'s not preachy or boring. it just never gets old, despite my having seen it some 15 or more times')
# Out:
# 'probably  all-time favorite movie,  story  selflessness, sacrifice  dedication   noble cause,    preachy  boring.   never gets old, despite   seen   15   times'

# %%
df.head(5)
# Out:
#                                               Review Sentiment
# 0  narrative sublime. it's never included in crit...  positive
# 1  "this is by far the worst film i have seen in ...  negative
# 2  i saw this on the shelves at the rental place ...  negative
# 3  "this film is about a teen who is struggling w...  positive
# 4  once again elmer is faced with the dilemma of ...  positive

# %%
df['Review'] = df['Review'].apply(remove_stopwords)

# %%
df.head(5)
# Out:
#                                               Review Sentiment
# 0  narrative sublime.  never included  critics' c...  positive
# 1  "this   far  worst film   seen   entire life. ...  negative
# 2   saw    shelves   rental place    rented every...  negative
# 3  "this film    teen   struggling   social statu...  positive
# 4    elmer  faced   dilemma    shoot. bugs  daffy...  positive

# %% [markdown]
# ## **Removing Emoji's Handle**

# %%
import re
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
remove_emoji("Loved the movie. It was 😘😘")
# Out:
# 'Loved the movie. It was '

# %%
remove_emoji("Lmao 😂😂")
# Out:
# 'Lmao '

# %%
# !pip install emoji
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 2.2 MB/s eta 0:00:00
# ...

# %%
import emoji
print(emoji.demojize('Python is 🔥'))
# Out:
# Python is :fire:

# %%
print(emoji.demojize('Loved the movie. It was 😘'))
# Out:
# Loved the movie. It was :face_blowing_a_kiss:

# %% [markdown]
# ## **Tokenization**

# %%
# word tokenization
text = "I am going to pakistan"
text.split()
# Out:
# ['I', 'am', 'going', 'to', 'pakistan']

# %%
# sentence level tokenization
text = "I am going to pakistan. I will stay there for 3 weeks"
text.split('.')
# Out:
# ['I am going to pakistan', ' I will stay there for 3 weeks']

# %%
# with regular expressions
# word level
import re
sent3 = 'I am going to delhi!'
tokens = re.findall("[\w']+", sent3)
tokens
# Out:
# ['I', 'am', 'going', 'to', 'delhi']

# %%
# sentence level
text = """Lorem Ipsum is simply dummy text of the printing and typesetting industry?
Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,
when an unknown printer took a galley of type and scrambled it to make a type specimen book."""
sentences = re.compile('[.!?] ').split(text)
sentences
# Out:
# ["Lorem Ipsum is simply dummy text of the printing and typesetting industry?\nLorem Ipsum has been the industry's standard dummy text ever since the 1500s,\nwhen an unknown printer took a galley of type and scrambled it to make a type specimen book."]

# %%
# Using NLTK
from nltk.tokenize import word_tokenize,sent_tokenize
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
sent1 = "I am going to pakistan"
word_tokenize(sent1)
# Out:
# ['I', 'am', 'going', 'to', 'pakistan']

# %%
text = """Lorem Ipsum is simply dummy text of the printing and typesetting industry?
Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,
when an unknown printer took a galley of type and scrambled it to make a type specimen book."""

sent_tokenize(text)
# Out:
# ['Lorem Ipsum is simply dummy text of the printing and typesetting industry?',
#  "Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,\nwhen an unknown printer took a galley of type and scrambled it to make a type specimen book."]

# %%
# using spacy
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc1 = nlp(sent1)
doc2 = nlp(text)

# %%
doc1
# Out:
# I am going to pakistan

# %%
for token in doc1:
    print(token)
# Out:
# I
# am
# going
# to
# pakistan

# %%
df.head()
# Out:
#                                               Review Sentiment
# 0  narrative sublime. It's never included in crit...  positive
# 1  "This is by far the worst film I have seen in ...  negative
# 2  I saw this on the shelves at the rental place ...  negative
# 3  "This film is about a teen who is struggling w...  positive
# 4  Once again Elmer is faced with the dilemma of ...  positive
