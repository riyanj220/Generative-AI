# %%
# !pip install transformers[sentencepiece] datasets sacrebleu rouge_score py7zr -q

# %%
# !pip install --upgrade accelerate
# !pip uninstall -y transformers accelerate
# !pip install transformers accelerate

# %%
# !pip install evaluate

# %%
import evaluate
from transformers import pipeline,set_seed
from datasets import load_dataset, load_from_disk
import matplotlib.pyplot as plt
import pandas as pd
# from evaluate import load_metric

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

import nltk
from nltk.tokenize import sent_tokenize

from tqdm import tqdm
import torch

nltk.download("punkt")

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
from datasets import load_dataset

# Load the dataset
dataset = load_dataset("lavita/medical-qa-datasets", split="train[:1000]")

# Inspect the dataset splits
print(dataset)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-655240290.py in <cell line: 0>()
#       2
#       3 # Load the dataset
# ----> 4 dataset = load_dataset("lavita/medical-qa-datasets", split="train[:1000]")
#       5
#       6 # Inspect the dataset splits
#
# /usr/local/lib/python3.11/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1390
#    1391     # Create a dataset builder
# -> 1392     builder_instance = load_dataset_builder(
#    1393         path=path,
#    1394         name=name,
#
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_ckpt = "Akhil-Theerthala/Kuvera-8B-qwen3-v0.2.1"

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)

# Load model
model = AutoModelForCausalLM.from_pretrained(model_ckpt).to(device)

# .to(device) literally transfers all model weights to the GPU memory so you can do training or inference efficiently.
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.58G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ...
